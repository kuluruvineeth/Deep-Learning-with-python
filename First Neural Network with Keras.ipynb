# %% [markdown]
# # steps to build neural network
# 1. Load Data
# 2. Define Model
# 3. Compile Model
# 4. Fit Model
# 5. Evaluate Model

# %% [markdown]
# ## 1. Load Data

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.data.csv",delimiter=",")

# split into input(X) and output(Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# ## 2. Define Model
# * Models in keras are defined as sequence of layers.
# * Fully connected layers are defined using the **Dense** class.

# %%
# create model
model = Sequential()
# first hidden layer has 12 neurons and expects 8 input variables
model.add(Dense(12, input_dim=8, activation='relu'))
# second hidden layer has 8 neurons
model.add(Dense(8, activation='relu'))
# output layer has i neuron to predict the class
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 3. Compile Model
# * we must specify the loss function to use to evaluate a set of weights,the optimizer used to search through different weights for the network.
# * we will use logarithm loss for binary classification called **binary_crossentropy**.
# * we will also use effivcient gradient descent algorithm **adam** for optimization.

# %%
# compile model
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# ## 4. Fit Model
# * The training process will run for a fixed number of iterations through the dataset called epochs,that we must specify using the **nb_epoch**.
# * We can also set the number of instances that are evaluated before a weight update in the newtork is performed called the **batch size**

# %%
# Fit the model
model.fit(X,Y,epochs=150,batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 12.3817 - accuracy: 0.3596
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.1463 - accuracy: 0.5233
# Epoch 3/150
# 77/77 [==============================] - 0s 842us/step - loss: 0.7180 - accuracy: 0.6237
# Epoch 4/150
# 77/77 [==============================] - 0s 955us/step - loss: 0.7564 - accuracy: 0.6181
# Epoch 5/150
# 77/77 [==============================] - 0s 929us/step - loss: 0.7031 - accuracy: 0.6220
# Epoch 6/150
# 77/77 [==============================] - 0s 847us/step - loss: 0.7133 - accuracy: 0.6132
# Epoch 7/150
# 77/77 [==============================] - 0s 887us/step - loss: 0.6790 - accuracy: 0.6579
# Epoch 8/150
# 77/77 [==============================] - 0s 904us/step - loss: 0.6648 - accuracy: 0.6521
# Epoch 9/150
# 77/77 [==============================] - 0s 946us/step - loss: 0.6630 - accuracy: 0.6612
# Epoch 10/150
# ...

# %% [markdown]
# ## 5. Evaluate Model

# %%
# evaluate the model
scores = model.evaluate(X,Y)
print("%s : %.2f"%(model.metrics_names[1],scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 936us/step - loss: 0.4871 - accuracy: 0.7669
# accuracy : 76.69
